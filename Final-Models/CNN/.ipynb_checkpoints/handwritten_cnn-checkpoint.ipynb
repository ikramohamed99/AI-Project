# %%
import tensorflow as tf

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize
from skimage.transform import resize
from tensorflow.keras.optimizers import SGD

np.random.seed(42)

import warnings
warnings.filterwarnings("ignore")

#read image
img = cv2.imread('handwritten_alphabet2.jpg')

#grayscale
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

#binarize 
ret,thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY_INV)

#find contours
ctrs, hier = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, 
cv2.CHAIN_APPROX_SIMPLE)

#sort contours
def sort_contours(contour, cols):
    tolerance_factor = 10
    origin = cv2.boundingRect(contour)
    return ((origin[1] // tolerance_factor) * tolerance_factor) * cols + origin[0]

sorted_ctrs = sorted(ctrs, key=lambda x:sort_contours(x, img.shape[1]))


segments = []
for i, ctr in enumerate(sorted_ctrs):
    # Get bounding box
    x, y, w, h = cv2.boundingRect(ctr)
    
    area = cv2.contourArea(ctr)
    if h>10 and w>1:
        # Getting ROI
        roi = img[y:y+h, x:x+w]

        # show ROI
        roi = resize(roi, (28, 28, 1))
        #roi = np.reshape(roi, (28,28))
        segments.append(roi)
        #cv2.imshow('charachter'+str(i), roi)
        cv2.rectangle(img,(x,y),( x + w, y + h ),(90,0,255),2)
        #print(roi.shape)

train = np.array(segments)
print('Segments shape: ', train.shape)

plt.matshow(img)
# Out:
# Segments shape:  (52, 28, 28, 1)

# %%
letter_map = dict(zip(['A','a','B','b','C','c','D','d','E','e','F','f','G','g','H','h','I','i','J', 'j','K','k','L', 'l', 'M', 'm','N', 'n','O', 'o','P', 'p', 'Q', 'q', 'R', 'r', 'S', 's', 'T', 't', 'U', 'u', 'V', 'v', 'W', 'w', 'X', 'x', 'Y', 'y', 'Z', 'z'], range(0,52)))

# %%
unique_target = list('ABCDEFGHIJKLMNOPQRSTUVWXYZbdfhkiacegmljnopqrstuvwxyz')

train_target = []
for i in unique_target:
    train_target.append(letter_map[i])
    
train_target = np.array(train_target)

print('Target shape:', train_target.shape)
# Out:
# Target shape: (52,)

# %%
for i in range(0, train.shape[0]):
    plt.matshow(np.reshape(train, (52, 28,28))[i], cmap = 'gray')
    plt.xlabel('Target is ' + train_target[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-fbebf6504e3c> in <module>
#       1 for i in range(0, train.shape[0]):
#       2     plt.matshow(np.reshape(train, (52, 28,28))[i], cmap = 'gray')
# ----> 3     plt.xlabel('Target is ' + train_target[i])
#
# TypeError: can only concatenate str (not "numpy.int32") to str

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import History
from tensorflow.keras.callbacks import LearningRateScheduler
from skimage.transform import resize

#read image
img = cv2.imread('handwritten_extract2.jpg')

#grayscale
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

#binarize 
ret,thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY_INV)

#find contours
ctrs, hier = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, 
cv2.CHAIN_APPROX_SIMPLE)

#sort contours
def sort_contours(contour, cols):
    tolerance_factor = 10
    origin = cv2.boundingRect(contour)
    return ((origin[1] // tolerance_factor) * tolerance_factor) * cols + origin[0]

sorted_ctrs = sorted(ctrs, key=lambda x:sort_contours(x, img.shape[1]))

segments = []
for i, ctr in enumerate(sorted_ctrs):
    # Get bounding box
    x, y, w, h = cv2.boundingRect(ctr)
    
    area = cv2.contourArea(ctr)
    if h>5:
        # Getting ROI
        roi = img[y:y+h, x:x+w]

        # show ROI
        roi = resize(roi, (28, 28, 1))
        #roi = np.reshape(roi, (28,28))
        segments.append(roi)
        #cv2.imshow('charachter'+str(i), roi)
        cv2.rectangle(img,(x,y),( x + w, y + h ),(90,0,255),2)
        #print(roi.shape)

test = np.array(segments)
print('Segments shape: ', test.shape)

plt.matshow(img)
# Out:
# Segments shape:  (508, 28, 28, 1)

# %%
unique_target = list('...')

test_target = []
for i in unique_target:
    test_target.append(letter_map[i])
    
test_target = np.array(test_target)

# %%
n_samples = len(test)

# %%
X_train = train
y_train = train_target
X_val = test[:round(.8 * n_samples)]
y_val = test_target[:round(.8 * n_samples)]
X_test = test[round(.8 * n_samples):]
y_test = test_target[round(.8 * n_samples):]

# %%
X_train.shape
# Out:
# (52, 28, 28, 1)

# %%
y_train.shape
# Out:
# (52,)

# %%
X_train[0].shape
# Out:
# (28, 28, 1)

# %%
import matplotlib.pyplot as plt

plt.imshow(X_train[0, :, :, 0],cmap=plt.cm.binary)
plt.show()

# %%
print(list(letter_map.keys())[list(letter_map.values()).index(train_target[0])])
# Out:
# A

# %%
X_train = tf.keras.utils.normalize(X_train, axis=1)
X_val = tf.keras.utils.normalize(X_val, axis=1)
X_test = tf.keras.utils.normalize(X_test, axis=1)

# %%
plt.imshow(X_train[0, :, :, 0],cmap=plt.cm.binary)
plt.show()

# %%
epochs = 20
learning_rate = 0.001

# %%
from tensorflow.keras.optimizers import Adam

# %%
adam = Adam(lr=learning_rate)

# %%
model = tf.keras.models.Sequential()

# %%
# model.add(tf.keras.layers.Conv2D(128, (3, 3), input_shape=X_train.shape[1:], activation=tf.nn.relu))
# model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

# %%
model.add(tf.keras.layers.Conv2D(128, (3, 3), activation=tf.nn.relu))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

# %%
model.add(tf.keras.layers.Flatten())

# %%
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))

# %%
logits = model.add(tf.keras.layers.Dense(max(train_target) + 1, activation=tf.nn.softmax))

# %%
model.compile(optimizer=adam,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model_fit = model.fit(X_train, y_train, epochs=epochs, batch_size = 10, validation_data=(X_val, y_val))
# Out:
# Train on 52 samples, validate on 406 samples
# Epoch 1/20
# 52/52 [==============================] - 1s 12ms/sample - loss: 4.0540 - acc: 0.0000e+00 - val_loss: 3.9195 - val_acc: 0.0074
# Epoch 2/20
# 52/52 [==============================] - 0s 9ms/sample - loss: 3.9344 - acc: 0.0192 - val_loss: 3.9357 - val_acc: 0.0394
# Epoch 3/20
# 52/52 [==============================] - 1s 10ms/sample - loss: 3.8915 - acc: 0.1346 - val_loss: 3.8920 - val_acc: 0.0443
# Epoch 4/20
# 52/52 [==============================] - 0s 9ms/sample - loss: 3.8256 - acc: 0.2885 - val_loss: 3.8172 - val_acc: 0.0074
# Epoch 5/20
# 52/52 [==============================] - 1s 11ms/sample - loss: 3.7414 - acc: 0.2115 - val_loss: 3.7276 - val_acc: 0.1108
# Epoch 6/20
# 52/52 [==============================] - 1s 12ms/sample - loss: 3.6298 - acc: 0.1731 - val_loss: 3.6022 - val_acc: 0.1724
# Epoch 7/20
# 52/52 [==============================] - 1s 11ms/sample - loss: 3.4917 - acc: 0.1731 - val_loss: 3.3208 - val_acc: 0.2709
# Epoch 8/20
# 52/52 [==============================] - 1s 13ms/sample - loss: 3.2922 - acc: 0.3269 - val_loss: 3.2137 - val_acc: 0.3227
# Epoch 9/20
# 52/52 [==============================] - 0s 9ms/sample - loss: 3.0539 - acc: 0.5192 - val_loss: 3.1189 - val_acc: 0.4433
# Epoch 10/20
# 52/52 [==============================] - 0s 10ms/sample - loss: 2.7865 - acc: 0.5769 - val_loss: 2.7927 - val_acc: 0.5419
# Epoch 11/20
# 52/52 [==============================] - 0s 9ms/sample - loss: 2.4344 - acc: 0.6346 - val_loss: 2.5327 - val_acc: 0.6281
# Epoch 12/20
# 52/52 [==============================] - 0s 9ms/sample - loss: 2.1099 - acc: 0.6923 - val_loss: 2.1729 - val_acc: 0.7340
# Epoch 13/20
# 52/52 [==============================] - 0s 9ms/sample - loss: 1.7144 - acc: 0.7692 - val_loss: 1.8686 - val_acc: 0.7414
# Epoch 14/20
# 52/52 [==============================] - 0s 9ms/sample - loss: 1.3629 - acc: 0.8077 - val_loss: 1.5832 - val_acc: 0.7906
# Epoch 15/20
# 52/52 [==============================] - 0s 10ms/sample - loss: 1.1360 - acc: 0.7308 - val_loss: 1.4011 - val_acc: 0.7980
# Epoch 16/20
# 52/52 [==============================] - 0s 9ms/sample - loss: 0.7727 - acc: 0.9615 - val_loss: 1.1830 - val_acc: 0.7709
# Epoch 17/20
# 52/52 [==============================] - 0s 9ms/sample - loss: 0.6628 - acc: 0.8846 - val_loss: 1.0776 - val_acc: 0.8399
# Epoch 18/20
# 52/52 [==============================] - 0s 8ms/sample - loss: 0.4621 - acc: 0.9808 - val_loss: 1.0625 - val_acc: 0.8399
# Epoch 19/20
# 52/52 [==============================] - 1s 11ms/sample - loss: 0.3572 - acc: 1.0000 - val_loss: 1.0305 - val_acc: 0.7660
# Epoch 20/20
# 52/52 [==============================] - 1s 11ms/sample - loss: 0.3173 - acc: 0.9615 - val_loss: 1.0036 - val_acc: 0.7783

# %%
val_loss, val_acc = model.evaluate(X_val, y_val)
print('Loss: ' + str(val_loss))
print('Accuracy: ' + str(val_acc))
# Out:
# 406/406 [==============================] - 0s 680us/sample - loss: 1.0036 - acc: 0.7783
# Loss: 1.0035996043623374
# Accuracy: 0.77832514

# %%
from sklearn.metrics import confusion_matrix
y_val_pred = model.predict_classes(X_val)
c_matrix = confusion_matrix(y_val, y_val_pred)

# %%
plt.matshow(c_matrix, cmap=plt.cm.gray)
plt.show()

# %%
# plot loss
fig, ax = plt.subplots(1, 1, figsize=(10,6))
ax.plot(np.sqrt(model_fit.history['loss']), 'r', label='train')
ax.plot(np.sqrt(model_fit.history['val_loss']), 'b' ,label='val')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'Loss', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# %%
# Plot accuracy
fig, ax = plt.subplots(1, 1, figsize=(10,6))
ax.plot(np.sqrt(model_fit.history['acc']), 'r', label='train')
ax.plot(np.sqrt(model_fit.history['val_acc']), 'b' ,label='val')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'Accuracy', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import utils
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras import datasets

from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import History

from tensorflow.keras import losses
from sklearn.utils import shuffle

# %%
# solution
epochs = 20
learning_rate = 0.1 # initial learning rate

decay_rate = learning_rate / epochs
# define the optimizer function
sgd = SGD(lr=learning_rate, nesterov=False)

input_dim = X_train.shape[1]
num_classes = 10
batch_size = 20

# build the model
lr_model = tf.keras.models.Sequential()

lr_model.add(tf.keras.layers.Conv2D(128, (3, 3), input_shape=X_train.shape[1:], activation=tf.nn.relu))
lr_model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

lr_model.add(tf.keras.layers.Conv2D(128, (3, 3), activation=tf.nn.relu))
lr_model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

lr_model.add(tf.keras.layers.Flatten())

lr_model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))

lr_model.add(tf.keras.layers.Dense(max(train_target) + 1, activation=tf.nn.softmax))


#compile
lr_model.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# define the learning rate change 
def exp_decay(epoch):
    lrate = learning_rate * np.exp(-decay_rate*epoch)
    return lrate
    
# learning schedule callback
loss_history = History()
lr_rate = LearningRateScheduler(exp_decay)
callbacks_list = [loss_history, lr_rate]

# you invoke the LearningRateScheduler during the .fit() phase
lr_model_model_hist = lr_model.fit(X_train, y_train,
                                    batch_size=batch_size,
                                    epochs=epochs,
                                    callbacks=callbacks_list,
                                    verbose=1,
                                    validation_data=(X_test, y_test))
# Out:
# Train on 52 samples, validate on 102 samples
# Epoch 1/20
# 52/52 [==============================] - 0s 9ms/sample - loss: 3.9553 - acc: 0.0192 - val_loss: 3.9478 - val_acc: 0.0882
# Epoch 2/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 3.9559 - acc: 0.0192 - val_loss: 3.9462 - val_acc: 0.0882
# Epoch 3/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 3.9530 - acc: 0.0192 - val_loss: 3.9483 - val_acc: 0.0882
# Epoch 4/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 3.9525 - acc: 0.0192 - val_loss: 3.9472 - val_acc: 0.0882
# Epoch 5/20
# 52/52 [==============================] - 0s 6ms/sample - loss: 3.9524 - acc: 0.0192 - val_loss: 3.9465 - val_acc: 0.0882
# Epoch 6/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 3.9522 - acc: 0.0192 - val_loss: 3.9464 - val_acc: 0.0882
# Epoch 7/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 3.9516 - acc: 0.0192 - val_loss: 3.9448 - val_acc: 0.0882
# Epoch 8/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 3.9507 - acc: 0.0192 - val_loss: 3.9451 - val_acc: 0.0882
# Epoch 9/20
# 52/52 [==============================] - 0s 6ms/sample - loss: 3.9508 - acc: 0.0192 - val_loss: 3.9450 - val_acc: 0.0882
# Epoch 10/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 3.9504 - acc: 0.0192 - val_loss: 3.9442 - val_acc: 0.0882
# Epoch 11/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 3.9501 - acc: 0.0192 - val_loss: 3.9439 - val_acc: 0.0882
# Epoch 12/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 3.9489 - acc: 0.0192 - val_loss: 3.9433 - val_acc: 0.0882
# Epoch 13/20
# 52/52 [==============================] - 0s 7ms/sample - loss: 3.9488 - acc: 0.0192 - val_loss: 3.9430 - val_acc: 0.0882
# Epoch 14/20
# 52/52 [==============================] - 0s 7ms/sample - loss: 3.9486 - acc: 0.0192 - val_loss: 3.9432 - val_acc: 0.0882
# Epoch 15/20
# 52/52 [==============================] - 0s 6ms/sample - loss: 3.9482 - acc: 0.0192 - val_loss: 3.9438 - val_acc: 0.0882
# Epoch 16/20
# 52/52 [==============================] - 0s 8ms/sample - loss: 3.9474 - acc: 0.0192 - val_loss: 3.9444 - val_acc: 0.0882
# Epoch 17/20
# 52/52 [==============================] - 0s 7ms/sample - loss: 3.9472 - acc: 0.0192 - val_loss: 3.9434 - val_acc: 0.0882
# Epoch 18/20
# 52/52 [==============================] - 0s 7ms/sample - loss: 3.9469 - acc: 0.0192 - val_loss: 3.9419 - val_acc: 0.0882
# Epoch 19/20
# 52/52 [==============================] - 0s 8ms/sample - loss: 3.9473 - acc: 0.0192 - val_loss: 3.9417 - val_acc: 0.0882
# Epoch 20/20
# 52/52 [==============================] - 0s 6ms/sample - loss: 3.9451 - acc: 0.0192 - val_loss: 3.9438 - val_acc: 0.0882

# %% [markdown]
# ## Loss and accuracy curves

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))
ax.plot(np.sqrt(lr_model_model_hist.history['lr']), 'r', label='Learning rate')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'Learning rate', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# %%
# Plot the loss function
fig, ax = plt.subplots(1, 1, figsize=(10,6))
ax.plot(np.sqrt(lr_model_model_hist.history['loss']), 'r', label='train')
ax.plot(np.sqrt(lr_model_model_hist.history['val_loss']), 'b' ,label='val')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'Loss', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)
# how loss decreses with decreasing learning rate

# %%
# Function to create model, required for KerasClassifier
def create_model():
    # create model
    epochs = 20
    learning_rate = 0.1
    decay_rate = learning_rate / epochs
    sgd = SGD(lr=learning_rate, decay=decay_rate, nesterov=False)
    
    model = tf.keras.models.Sequential()

    model.add(tf.keras.layers.Conv2D(128, (3, 3), input_shape=X_train.shape[1:], activation=tf.nn.relu))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

    model.add(tf.keras.layers.Conv2D(128, (3, 3), activation=tf.nn.relu))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

    model.add(tf.keras.layers.Flatten())

    model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
    
    model.compile(optimizer=sgd,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
#from create_model import create_model
from sklearn.model_selection import GridSearchCV
new_model = tf.keras.wrappers.scikit_learn.KerasClassifier(build_fn=create_model, verbose=0)

# define the grid search parameters
batch_size = [10, 20, 40, 60, 80, 100]
epochs = [10, 50, 100]
param_grid = dict(batch_size=batch_size, epochs=epochs)
grid = GridSearchCV(estimator=new_model, param_grid=param_grid, n_jobs=1, cv=3)
grid_result = grid.fit(X_train, y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

# %% [markdown]
# ## Final Predict

# %% [markdown]
# #### Using the best parameters

# %%
epochs = 20
learning_rate = 0.001

from tensorflow.keras.optimizers import Adam

adam = Adam(lr=learning_rate)

model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Conv2D(128, (3, 3), input_shape=X_train.shape[1:], activation=tf.nn.relu))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(tf.keras.layers.Conv2D(128, (3, 3), activation=tf.nn.relu))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))

logits = model.add(tf.keras.layers.Dense(max(train_target) + 1, activation=tf.nn.softmax))

model.compile(optimizer=adam,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(X_train, y_train, epochs=epochs, batch_size = 10)
# Out:
# Train on 52 samples
# Epoch 1/20
# 52/52 [==============================] - 0s 8ms/sample - loss: 3.9789 - acc: 0.0192
# Epoch 2/20
# 52/52 [==============================] - 0s 7ms/sample - loss: 3.9519 - acc: 0.0192
# Epoch 3/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 3.9482 - acc: 0.0385
# Epoch 4/20
# 52/52 [==============================] - 0s 6ms/sample - loss: 3.9453 - acc: 0.0769
# Epoch 5/20
# 52/52 [==============================] - 0s 6ms/sample - loss: 3.9390 - acc: 0.0962
# Epoch 6/20
# 52/52 [==============================] - 0s 7ms/sample - loss: 3.9226 - acc: 0.0577
# Epoch 7/20
# 52/52 [==============================] - 0s 6ms/sample - loss: 3.8854 - acc: 0.1731
# Epoch 8/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 3.8348 - acc: 0.0769
# Epoch 9/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 3.7134 - acc: 0.0769
# Epoch 10/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 3.5070 - acc: 0.1731
# Epoch 11/20
# 52/52 [==============================] - 0s 4ms/sample - loss: 3.1892 - acc: 0.3654
# Epoch 12/20
# 52/52 [==============================] - 0s 4ms/sample - loss: 2.7517 - acc: 0.3654
# Epoch 13/20
# 52/52 [==============================] - 0s 4ms/sample - loss: 2.1731 - acc: 0.4615
# Epoch 14/20
# 52/52 [==============================] - 0s 4ms/sample - loss: 1.5743 - acc: 0.5769
# Epoch 15/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 1.2254 - acc: 0.7308
# Epoch 16/20
# 52/52 [==============================] - 0s 4ms/sample - loss: 0.8858 - acc: 0.7692
# Epoch 17/20
# 52/52 [==============================] - 0s 4ms/sample - loss: 0.6727 - acc: 0.8269
# Epoch 18/20
# 52/52 [==============================] - 0s 4ms/sample - loss: 0.4465 - acc: 0.8846
# Epoch 19/20
# 52/52 [==============================] - 0s 4ms/sample - loss: 0.3441 - acc: 0.9423
# Epoch 20/20
# 52/52 [==============================] - 0s 5ms/sample - loss: 0.2222 - acc: 0.9423

# %%
y_pred = model.predict_classes(test)

# %%
target = []
for i in range(0, len(test_target)):
    target.append(list(letter_map.keys())[list(letter_map.values()).index(test_target[i])])

# %%
prediction = []
for i in range(0, len(y_pred)):
    prediction.append(list(letter_map.keys())[list(letter_map.values()).index(y_pred[i])])
